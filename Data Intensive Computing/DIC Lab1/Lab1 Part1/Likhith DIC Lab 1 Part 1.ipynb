# %% [markdown]
# # Partner : Rahul Mallu

# %%
sales1<-c(12,14,16,29,30,45,19,20,16, 19, 34, 20)
sales2<-rpois(12,34) # random numbers, Poisson distribution, mean at 34, 12 numbers
par(bg="cornsilk")
plot(sales1, col="blue", type="o", ylim=c(0,100), xlab="Month", ylab="Sales" )
title(main="Sales by Month")
lines(sales2, type="o", pch=22, lty=2, col="red")
grid(nx=NA, ny=NULL)
legend("topright", inset=.05, c("Sales1","Sales2"), fill=c("blue","red"), horiz=TRUE)
# Out:
# Plot with title "Sales by Month"

# %%
sales<-read.table(file.choose(), header=T)
sales # to verify that data has been read
barplot(as.matrix(sales), main="Sales Data", ylab= "Total",beside=T, col=rainbow(5))
# Out:
#    Sales1 Sales2
# 1  34     45
# 2  23     23
# 3  12     56
# 4  29     34
# 5  34     45
# 6  34     56
# 7  12     89
# 8  80     36
# 9  80     44
# 10 56     66
# 11 55     60
# 12 45     23
# Plot with title "Sales Data"

# %%
fn<-boxplot(sales,col=c("orange","green"))$stats
text(1.45, fn[3,2], paste("Median =", fn[3,2]), adj=0, cex=.7)
text(0.45, fn[3,1],paste("Median =", fn[3,1]), adj=0, cex=.7)
grid(nx=NA, ny=NULL)
# Out:
# plot without title

# %%
setwd('C:/Users/bunny/Desktop/DIC') # setting current directory

# %%
fb1<-read.csv(file.choose())

# %%
aapl1<-read.csv(file.choose())

# %%
par(bg="cornsilk")
plot(aapl1$Adj.Close, col="blue", type="o", ylim=c(0,100), xlab="Days", ylab="Price" )
lines(fb1$Adj.Close, type="o", pch=22, lty=2, col="red")
legend("topright", inset=.05, c("Apple","Facebook"), fill=c("blue","red"), horiz=TRUE)
# Out:
# Error in plot(aapl1$Adj.Close, col = "blue", type = "o", ylim = c(0, 100), : object 'aapl1' not found
# Traceback:
#
# 1. plot(aapl1$Adj.Close, col = "blue", type = "o", ylim = c(0, 100),
#  .     xlab = "Days", ylab = "Price")

# %%
hist(aapl1$Adj.Close, col=rainbow(8))
# Out:
# Plot with title "Histogram of aapl1$Adj.Close"

# %%
library(help=datasets)

# %%
data()

# %%
summary(women)
# Out:
#      height         weight
#  Min.   :58.0   Min.   :115.0
#  1st Qu.:61.5   1st Qu.:124.5
#  Median :65.0   Median :135.0
#  Mean   :65.0   Mean   :136.7
#  3rd Qu.:68.5   3rd Qu.:148.0
#  Max.   :72.0   Max.   :164.0

# %%
summary(mpg)
head(mpg)
# Out:
#  manufacturer          model               displ            year
#  Length:234         Length:234         Min.   :1.600   Min.   :1999
#  Class :character   Class :character   1st Qu.:2.400   1st Qu.:1999
#  Mode  :character   Mode  :character   Median :3.300   Median :2004
#                                        Mean   :3.472   Mean   :2004
#                                        3rd Qu.:4.600   3rd Qu.:2008
#                                        Max.   :7.000   Max.   :2008
#       cyl           trans               drv                 cty
#  Min.   :4.000   Length:234         Length:234         Min.   : 9.00
#  1st Qu.:4.000   Class :character   Class :character   1st Qu.:14.00
#  Median :6.000   Mode  :character   Mode  :character   Median :17.00
#  Mean   :5.889                                         Mean   :16.86
#  3rd Qu.:8.000                                         3rd Qu.:19.00
#  Max.   :8.000                                         Max.   :35.00
#       hwy             fl               class
#  Min.   :12.00   Length:234         Length:234
#  1st Qu.:18.00   Class :character   Class :character
#  Median :24.00   Mode  :character   Mode  :character
#  Mean   :23.44
#  3rd Qu.:27.00
#  Max.   :44.00
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
head(uspop)
summary(uspop)
# Out:
# [1]  3.93  5.31  7.24  9.64 12.90 17.10
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    3.93   15.00   50.20   69.77  114.25  203.20

# %%
library(ggmap)
library(maptools)
library(maps)
# Out:
# Warning message:
# "package 'maptools' was built under R version 3.4.3"Loading required package: sp
# Warning message:
# "package 'sp' was built under R version 3.4.3"Checking rgeos availability: FALSE
#  	Note: when rgeos is not available, polygon geometry 	computations in maptools depend on gpclib,
#  	which has a restricted licence. It is disabled by default;
#  	to enable gpclib, type gpclibPermit()
# Warning message:
# "package 'maps' was built under R version 3.4.3"

# %%
visited <- c("SFO", "Chennai", "London", "Melbourne", "Lima,Peru", "Johannesbury, SA")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("world", fill=TRUE, col="white", bg="lightblue", ylim=c(-60, 90), mar=c(0,0,0,0))
points(visit.x,visit.y, col="red", pch=36)
# Out:
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=SFO&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Chennai&sensor=false
# Warning message:
# "geocode failed with status OVER_QUERY_LIMIT, location = "Chennai""Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=London&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Melbourne&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Lima,Peru&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Johannesbury,%20SA&sensor=false
# plot without title

# %%
library("ggmap")
library("maptools")
library(maps)
visited <- c("SFO", "New York", "Buffalo", "Dallas, TX","Baltimore")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("state", fill=TRUE, col=rainbow(50), bg="lightblue", mar=c(0,0,0,0))
points(visit.x,visit.y, col="yellow", pch=36)
# Out:
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=SFO&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=New%20York&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Buffalo&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Dallas,%20TX&sensor=false
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Baltimore&sensor=false
# plot without title

# %%
library(lattice)
attach(mtcars)
splom(mtcars[c(1,3,4,5,6)], main="MTCARS Data")
splom(mtcars[c(1,3,4,6)], main="MTCARS Data")
splom(mtcars[c(1,3,4,6)], col=rainbow(),main="MTCARS Data")
# Out:
# The following object is masked from package:ggplot2:
#
#     mpg
# plot without title
# Error in rainbow(): argument "n" is missing, with no default
# Traceback:
#
# 1. splom(mtcars[c(1, 3, 4, 6)], col = rainbow(), main = "MTCARS Data")
# 2. splom.data.frame(mtcars[c(1, 3, 4, 6)], col = rainbow(), main = "MTCARS Data")
# 3. eval.parent(ccall)
# 4. eval(expr, p)
# 5. eval(expr, p)
# 6. lattice::splom(x = ~x, col = rainbow(), main = "MTCARS Data",
#  .     data = <environment>)
# 7. splom.formula(x = ~x, col = rainbow(), main = "MTCARS Data",
#  .     data = <environment>)
# 8. rainbow()
# plot without title

# %%
attach(rock)
splom(rock[c(1,2,3,4)],col=rainbow(10), main="ROCK Data")
# Out:
# The following objects are masked from rock (pos = 3):
#
#     area, peri, perm, shape
# plot without title

# %%
ggplot(data=ChickWeight)+geom_bar(mapping=aes(Diet))
# Out:
# plot without title

# %%
ggplot(data=ChickWeight)+geom_point(mapping=aes(Chick,Time,colour=Diet))
# Out:
# plot without title

# %%
ggplot(data=ChickWeight)+geom_histogram(mapping=aes(x=Time),binwidth=.5)
# Out:
# plot without title

# %%
ggplot(data=diamonds)+geom_smooth(mapping=aes(depth,price,group=cut,color=cut))
# Out:
# `geom_smooth()` using method = 'gam'
# plot without title

# %%
ggplot(data=diamonds)+geom_point(mapping=aes(carat,price,colour=cut))+facet_wrap(~cut,nrow=5)
# Out:
# plot without title
